# %%
# import pandas
import pandas as pd

# %%
#read initial cleaning of beer permit csv, drop extra index column
df = pd.read_csv("..\Beer_Restaurant_Success\cleaned_beer_dataset.csv")
df = df.drop(columns = "Unnamed: 0")
df.head()
# Out:
#    Permit #  Status Permit Type Permit SubType  Permit Sub Type Description  \
# 0  19-25846  ISSUED    BBPERMIT        ONSALES           BB - On Site Sales
# 1  16-20340  ISSUED    BBPERMIT        ONSALES           BB - On Site Sales
# 2  17-00205  ISSUED    BBPERMIT     WHOLESALES  BB - Wholesale, Distributor
# 3  19-25920  ISSUED    BBPERMIT     ONOFFSALES     BB - On & Off Site Sales
# 4  19-25985  ISSUED    BBPERMIT     ONOFFSALES     BB - On & Off Site Sales
#
#   Date Entered Date Issued       Parcel                    Business Name  \
# 0   01/24/2019  06/03/2019  16300030200          EXO-TIKKA INDIAN CUSINE
# 1   05/18/2016  09/23/2016  09114025000    Las Palmas Mexican Restaurant
# 2   11/03/2016  07/10/2017  09112001600               Fat Bottom Brewing
# 3   03/06/2019  06/13/2019  11714013900                  NASHVILLE CIGAR
# 4   04/22/2019  06/13/2019  08305018200  TAILGATE BREWERY EAST NASHVILLE
#
#                 Address       City State      Zip  \
# ...

# %%
# locate duplicate permit #s
df.loc[df.duplicated(subset = ["Permit #"])]
# Out:
#       Permit #  Status Permit Type Permit SubType Permit Sub Type Description  \
# 93    19-26100  ISSUED    BBPERMIT        ONSALES          BB - On Site Sales
# 96    19-26100  ISSUED    BBPERMIT        ONSALES          BB - On Site Sales
# 143   20-26512  ISSUED    BBPERMIT        ONSALES          BB - On Site Sales
# 170   19-25969  ISSUED    BBPERMIT        ONSALES          BB - On Site Sales
# 226   19-26050  ISSUED    BBPERMIT        ONSALES          BB - On Site Sales
# 261   21-27172  ISSUED    BBPERMIT     ONOFFSALES    BB - On & Off Site Sales
# 344   20-26511  ISSUED    BBPERMIT        ONSALES          BB - On Site Sales
# 361   19-25978  ISSUED    BBPERMIT     ONOFFSALES    BB - On & Off Site Sales
# 606   18-25733  ISSUED    BBPERMIT        ONSALES          BB - On Site Sales
# 736   19-25934  ISSUED    BBPERMIT        ONSALES          BB - On Site Sales
# 830   15-20109  ISSUED    BBPERMIT        ONSALES          BB - On Site Sales
# ...

# %%
# drop the duplicate rows
df.drop_duplicates(subset = ["Permit #"], inplace = True)

# %%
# check duplicates were dropped
df.loc[df.duplicated(subset = ["Permit #"])]
# Out:
# Empty DataFrame
# Columns: [Permit #, Status, Permit Type, Permit SubType, Permit Sub Type Description, Date Entered, Date Issued, Parcel, Business Name, Address, City, State, Zip, Mapped Location]
# Index: []

# %%
# create new csv

df.to_csv("beer_permit_no_dups.csv")
