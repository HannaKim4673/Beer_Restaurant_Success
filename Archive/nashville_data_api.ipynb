# %%
# Import the requests library.
import requests
# import socrata
from sodapy import Socrata
# import pandas
import pandas as pd

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.nashville.gov", None)

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("3wb6-xy3j", limit=2000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)
# Out:
# WARNING:root:Requests made without an app_token will be subject to strict throttling limits.

# %%
results_df
# Out:
#      permit_number  status permit_type permit_subtype  \
# 0         19-25846  ISSUED    BBPERMIT        ONSALES
# 1         16-20340  ISSUED    BBPERMIT        ONSALES
# 2         17-00205  ISSUED    BBPERMIT     WHOLESALES
# 3         19-25920  ISSUED    BBPERMIT     ONOFFSALES
# 4         19-25985  ISSUED    BBPERMIT     ONOFFSALES
# ...            ...     ...         ...            ...
# 1995     D21-27223  ISSUED    BBPERMIT        ONSALES
# 1996      21-27128  ISSUED    BBPERMIT        ONSALES
# 1997      21-27194  ISSUED    BBPERMIT        ONSALES
# 1998      21-27192  ISSUED    BBPERMIT        ONSALES
# 1999      21-27236  ISSUED    BBPERMIT       OFFSALES
#
#              sub_type_description             date_entered  \
# 0              BB - On Site Sales  2019-01-24T00:00:00.000
# 1              BB - On Site Sales  2016-05-18T00:00:00.000
# 2     BB - Wholesale, Distributor  2016-11-03T00:00:00.000
# 3        BB - On & Off Site Sales  2019-03-06T00:00:00.000
# 4        BB - On & Off Site Sales  2019-04-22T00:00:00.000
# ...                           ...                      ...
# 1995           BB - On Site Sales  2021-05-05T00:00:00.000
# 1996           BB - On Site Sales  2021-03-18T00:00:00.000
# 1997           BB - On Site Sales  2021-04-23T00:00:00.000
# 1998           BB - On Site Sales  2021-04-23T00:00:00.000
# 1999          BB - Off Site Sales  2021-05-11T00:00:00.000
#
#                   date_issued          parcel  \
# 0     2019-06-03T00:00:00.000     16300030200
# 1     2016-09-23T00:00:00.000     09114025000
# 2     2017-07-10T00:00:00.000     09112001600
# 3     2019-06-13T00:00:00.000     11714013900
# 4     2019-06-13T00:00:00.000     08305018200
# ...                       ...             ...
# 1995  2021-06-24T00:00:00.000     09306202600
# 1996  2021-06-24T00:00:00.000     10204010100
# 1997  2021-06-24T00:00:00.000     09311023300
# 1998  2021-06-24T00:00:00.000  135150A00300CO
# 1999  2021-06-25T00:00:00.000     08600020800
#
#                         business_name                  address  ...  \
# 0             EXO-TIKKA INDIAN CUSINE         5385  MT VIEW RD  ...
# 1       Las Palmas Mexican Restaurant     5821  Charlotte PIKE  ...
# 2                  Fat Bottom Brewing          800  44th AVE N  ...
# 3                     NASHVILLE CIGAR     4001  HILLSBORO PIKE  ...
# 4     TAILGATE BREWERY EAST NASHVILLE        811  GALLATIN AVE  ...
# ...                               ...                      ...  ...
# 1995                        CASA ROSA            308  BROADWAY  ...
# 1996                      SAIGON CAFE     6410  CHARLOTTE PIKE  ...
# 1997                     THE CORDELLE         45  LINDSLEY AVE  ...
# 1998               RUBY TUESDAY #5185  2304  MURFREESBORO PIKE  ...
# 1999                  7-ELEVEN 41072H   5430  OLD HICKORY BLVD  ...
#
#      council_district census_tract  \
# 0                  32     37015629
# 1                  20     37018101
# 2                  20     37013300
# 3                  25     37017901
# 4                   6     37011700
# ...               ...          ...
# 1995               19     37019500
# 1996               20     37018101
# 1997               19     37019500
# 1998               29     37015612
# 1999               11     37015623
#
#                                         mapped_location  \
# 0     {'latitude': '36.047649', 'longitude': '-86.64...
# 1     {'latitude': '36.149076', 'longitude': '-86.86...
# 2     {'latitude': '36.157013', 'longitude': '-86.83...
# 3     {'latitude': '36.104329', 'longitude': '-86.81...
# 4     {'latitude': '36.186415', 'longitude': '-86.74...
# ...                                                 ...
# 1995  {'latitude': '36.161356', 'longitude': '-86.77...
# 1996  {'latitude': '36.143456', 'longitude': '-86.87...
# 1997  {'latitude': '36.153932', 'longitude': '-86.76...
# 1998  {'latitude': '36.086399', 'longitude': '-86.64...
# 1999  {'latitude': '36.182712', 'longitude': '-86.60...
#
#      :@computed_region_c9xn_skx3 :@computed_region_sjpq_96s8  \
# 0                             30                       24062
# 1                             14                       15798
# 2                             14                       15798
# 3                             23                       15809
# 4                              7                       15548
# ...                          ...                         ...
# 1995                          13                       30396
# 1996                          14                       15798
# 1997                          13                       15800
# 1998                          27                       16166
# 1999                          17                       28805
#
#      :@computed_region_v3ji_vzam :@computed_region_gisn_y5cm  \
# 0                           2005                           7
# 1                           2005                           8
# 2                           2005                           8
# 3                           2005                           5
# 4                           2005                           2
# ...                          ...                         ...
# 1995                        2005                           1
# 1996                        2005                           8
# 1997                        2005                           1
# 1998                        2005                           7
# 1999                        2005                           3
#
#      :@computed_region_f73m_vb2k  \
# 0                              8
# 1                              5
# 2                              1
# 3                              6
# 4                              7
# ...                          ...
# 1995                           7
# 1996                           5
# 1997                           7
# 1998                           8
# 1999                           4
#
#                                        business_owner  \
# 0                                                 NaN
# 1     Las Palmas Mexican Restaurant Inc, Qurino Onate
# 2                              Fat Bottom Brewing Inc
# 3                              686 Bluberry Hill Road
# 4                                                 NaN
# ...                                               ...
# 1995                                              NaN
# 1996                                              NaN
# 1997                                              NaN
# 1998                                              NaN
# 1999                                    David Seltzer
#
#      :@computed_region_cfa7_hbpz
# 0                            NaN
# 1                            NaN
# 2                            642
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1995                          50
# 1996                         NaN
# 1997                         NaN
# 1998                         NaN
# 1999                         NaN
#
# [2000 rows x 23 columns]
