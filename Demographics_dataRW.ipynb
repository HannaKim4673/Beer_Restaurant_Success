# %%
# Dependencies
import pandas as pd

# %%
# csv to dataFrame
demo_df = pd.read_csv("../Beer_Restaurant_Success/Resources/demographics_by_zip.csv")
edu_df = pd.read_csv("../Beer_Restaurant_Success/Resources/education_by_zip.csv")
income_df = pd.read_csv("../Beer_Restaurant_Success/Resources/income_by_zip.csv")

# %%
# inspect demo_df headers
demo_df.head()
# Out:
#            GEO_ID                  NAME  \
# 0              id  Geographic Area Name
# 1  8600000US37013           ZCTA5 37013
# 2  8600000US37027           ZCTA5 37027
# 3  8600000US37067           ZCTA5 37067
# 4  8600000US37072           ZCTA5 37072
#
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                    97939
# 2                                    56117
# 3                                    29543
# 4                                    31492
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                            2456
# 2                                             765
# 3                                            1010
# 4                                             763
#
#                               DP05_0001PE  \
# 0  Percent!!SEX AND AGE!!Total population
# 1                                   97939
# ...

# %%
# change header to 1st row demo_df
new_header = demo_df.iloc[0] # assign index 0 as variable
demo_df = demo_df[1:] # drops orriginal headers
demo_df.columns = new_header # assigns header to previous index 0
demo_df.head()
# Out:
# 0              id Geographic Area Name  \
# 1  8600000US37013          ZCTA5 37013
# 2  8600000US37027          ZCTA5 37027
# 3  8600000US37067          ZCTA5 37067
# 4  8600000US37072          ZCTA5 37072
# 5  8600000US37076          ZCTA5 37076
#
# 0 Estimate!!SEX AND AGE!!Total population  \
# 1                                   97939
# 2                                   56117
# 3                                   29543
# 4                                   31492
# 5                                   40161
#
# 0 Margin of Error!!SEX AND AGE!!Total population  \
# 1                                           2456
# 2                                            765
# 3                                           1010
# 4                                            763
# 5                                           1183
#
# 0 Percent!!SEX AND AGE!!Total population  \
# 1                                  97939
# 2                                  56117
# ...

# %%
# view all headers
list(demo_df.columns.values)
# Out:
# ['id',
#  'Geographic Area Name',
#  'Estimate!!SEX AND AGE!!Total population',
#  'Margin of Error!!SEX AND AGE!!Total population',
#  'Percent!!SEX AND AGE!!Total population',
#  'Percent Margin of Error!!SEX AND AGE!!Total population',
#  'Estimate!!SEX AND AGE!!Total population!!Male',
#  'Margin of Error!!SEX AND AGE!!Total population!!Male',
#  'Percent!!SEX AND AGE!!Total population!!Male',
#  'Percent Margin of Error!!SEX AND AGE!!Total population!!Male',
#  'Estimate!!SEX AND AGE!!Total population!!Female',
#  'Margin of Error!!SEX AND AGE!!Total population!!Female',
#  'Percent!!SEX AND AGE!!Total population!!Female',
#  'Percent Margin of Error!!SEX AND AGE!!Total population!!Female',
#  'Estimate!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)',
#  'Margin of Error!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)',
#  'Percent!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)',
# ...

# %%
# select desired columns
demo_df = demo_df[['Geographic Area Name','Estimate!!SEX AND AGE!!Total population','Estimate!!SEX AND AGE!!Total population!!Male','Estimate!!SEX AND AGE!!Total population!!Female','Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population','Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!Male','Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!Female']]
demo_df.head()
# Out:
# 0 Geographic Area Name Estimate!!SEX AND AGE!!Total population  \
# 1          ZCTA5 37013                                   97939
# 2          ZCTA5 37027                                   56117
# 3          ZCTA5 37067                                   29543
# 4          ZCTA5 37072                                   31492
# 5          ZCTA5 37076                                   40161
#
# 0 Estimate!!SEX AND AGE!!Total population!!Male  \
# 1                                         47658
# 2                                         27888
# 3                                         14462
# 4                                         15327
# 5                                         19600
#
# 0 Estimate!!SEX AND AGE!!Total population!!Female  \
# 1                                           50281
# 2                                           28229
# 3                                           15081
# 4                                           16165
# ...

# %%
# rename headers of desired columns
demo_df = demo_df.rename(columns={'Geographic Area Name':'zip_code',
                                  'Estimate!!SEX AND AGE!!Total population':'total_population',
                                  'Estimate!!SEX AND AGE!!Total population!!Male':'total_male_population',
                                  'Estimate!!SEX AND AGE!!Total population!!Female':'total_female_popularion',
                                  'Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population':'18+',
                                  'Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!Male':'18+Male',
                                  'Estimate!!CITIZEN, VOTING AGE POPULATION!!Citizen, 18 and over population!!Female':'18+Female'})

demo_df.head()
# Out:
# 0     zip_code total_population total_male_population total_female_popularion  \
# 1  ZCTA5 37013            97939                 47658                   50281
# 2  ZCTA5 37027            56117                 27888                   28229
# 3  ZCTA5 37067            29543                 14462                   15081
# 4  ZCTA5 37072            31492                 15327                   16165
# 5  ZCTA5 37076            40161                 19600                   20561
#
# 0    18+ 18+Male 18+Female
# 1  59479   27984     31495
# 2  39146   19094     20052
# 3  20448    9573     10875
# 4  24099   11489     12610
# 5  30384   14353     16031

# %%
# split geographica area name column to remove zcta5
text = demo_df['zip_code'].str.split(' ', n=1, expand=True)
demo_df['text']=text[0]
demo_df['zip_code']=text[1]
demo_df=demo_df.drop(columns='text')
demo_df.head()
# Out:
# 0 zip_code total_population total_male_population total_female_popularion  \
# 1    37013            97939                 47658                   50281
# 2    37027            56117                 27888                   28229
# 3    37067            29543                 14462                   15081
# 4    37072            31492                 15327                   16165
# 5    37076            40161                 19600                   20561
#
# 0    18+ 18+Male 18+Female
# 1  59479   27984     31495
# 2  39146   19094     20052
# 3  20448    9573     10875
# 4  24099   11489     12610
# 5  30384   14353     16031

# %%
# inspect edu_df headers
edu_df.head()
# Out:
#            GEO_ID                  NAME  \
# 0              id  Geographic Area Name
# 1  8600000US37013           ZCTA5 37013
# 2  8600000US37027           ZCTA5 37027
# 3  8600000US37067           ZCTA5 37067
# 4  8600000US37072           ZCTA5 37072
#
#                                       S1501_C01_001E  \
# 0  Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT...
# 1                                               9099
# 2                                               4292
# 3                                               2278
# 4                                               2230
#
#                                       S1501_C01_001M  \
# 0  Margin of Error!!Total!!AGE BY EDUCATIONAL ATT...
# 1                                                858
# 2                                                594
# 3                                                524
# 4                                                344
#
#                                       S1501_C01_002E  \
# ...

# %%
# change header to 1st row edu_df
new_header = edu_df.iloc[0] # assign index 0 as variable
edu_df = edu_df[1:]  # drops orriginal headers
edu_df.columns = new_header # assigns header to previous index 0
edu_df.head()
# Out:
# 0              id Geographic Area Name  \
# 1  8600000US37013          ZCTA5 37013
# 2  8600000US37027          ZCTA5 37027
# 3  8600000US37067          ZCTA5 37067
# 4  8600000US37072          ZCTA5 37072
# 5  8600000US37076          ZCTA5 37076
#
# 0 Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years  \
# 1                                               9099
# 2                                               4292
# 3                                               2278
# 4                                               2230
# 5                                               3191
#
# 0 Margin of Error!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years  \
# 1                                                858
# 2                                                594
# 3                                                524
# 4                                                344
# 5                                                476
#
# ...

# %%
# view all headers
list(edu_df.columns.values)
# Out:
# ['id',
#  'Geographic Area Name',
#  'Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years',
#  'Margin of Error!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years',
#  'Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Less than high school graduate',
#  'Margin of Error!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Less than high school graduate',
#  'Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!High school graduate (includes equivalency)',
#  'Margin of Error!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!High school graduate (includes equivalency)',
#  "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Some college or associate's degree",
#  "Margin of Error!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Some college or associate's degree",
# ...

# %%
# select desired columns
edu_df=edu_df[["Geographic Area Name",
              "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years",
              "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Less than high school graduate",
              "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!High school graduate (includes equivalency)",
              "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Some college or associate's degree",
              "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Bachelor's degree or higher",
              "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 25 to 34 years",
              "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 25 to 34 years!!High school graduate or higher",
              "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 25 to 34 years!!Bachelor's degree or higher",
              "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 35 to 44 years",
              "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 35 to 44 years!!High school graduate or higher",
              "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 35 to 44 years!!Bachelor's degree or higher",
              "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 45 to 64 years",
              "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 45 to 64 years!!High school graduate or higher",
              "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 45 to 64 years!!Bachelor's degree or higher",
              "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 65 years and over",
              "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 65 years and over!!High school graduate or higher",
              "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 65 years and over!!Bachelor's degree or higher"]]
edu_df.head()
# Out:
# 0 Geographic Area Name  \
# 1          ZCTA5 37013
# 2          ZCTA5 37027
# 3          ZCTA5 37067
# 4          ZCTA5 37072
# 5          ZCTA5 37076
#
# 0 Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years  \
# 1                                               9099
# 2                                               4292
# 3                                               2278
# 4                                               2230
# 5                                               3191
#
# 0 Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Less than high school graduate  \
# 1                                               1073
# 2                                                643
# 3                                                227
# 4                                                336
# 5                                                278
#
# ...

# %%
# split geographic area name to remove ZCTA5
text_1 = edu_df['Geographic Area Name'].str.split(' ', n=1, expand=True)
edu_df['text']=text_1[0]
edu_df['Geographic Area Name']=text_1[1]
edu_df=edu_df.drop(columns='text')
edu_df.head()
# Out:
# 0 Geographic Area Name  \
# 1                37013
# 2                37027
# 3                37067
# 4                37072
# 5                37076
#
# 0 Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years  \
# 1                                               9099
# 2                                               4292
# 3                                               2278
# 4                                               2230
# 5                                               3191
#
# 0 Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Less than high school graduate  \
# 1                                               1073
# 2                                                643
# 3                                                227
# 4                                                336
# 5                                                278
#
# ...

# %%
# change datatype to numeric
edu_df = edu_df.astype(int)

# %%
# create new columns combining columns for desired datapoints
edu_df['18-24 highschool']= edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!High school graduate (includes equivalency)"] + edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Some college or associate's degree"]
edu_df['25-34 not high school graduate'] = edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 25 to 34 years"]-edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 25 to 34 years!!High school graduate or higher"]
edu_df['25-34 high school graduate']=edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 25 to 34 years!!High school graduate or higher"] - edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 25 to 34 years!!Bachelor's degree or higher"]
edu_df['35-44 not high school graduate'] = edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 35 to 44 years"] - edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 35 to 44 years!!High school graduate or higher"]
edu_df['35-44 high school graduate'] = edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 35 to 44 years!!High school graduate or higher"] - edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 35 to 44 years!!Bachelor's degree or higher"]
edu_df['45-64 not high school graduate'] = edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 45 to 64 years"]-edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 45 to 64 years!!High school graduate or higher"]
edu_df['45-64 high school graduate'] = edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 45 to 64 years!!High school graduate or higher"] = edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 45 to 64 years!!Bachelor's degree or higher"]
edu_df['65 and up not high school graduate'] = edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 65 years and over"] - edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 65 years and over!!High school graduate or higher"]
edu_df['65 and up high school graduate'] = edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 65 years and over!!High school graduate or higher"] - edu_df["Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 65 years and over!!Bachelor's degree or higher"]
edu_df.head()
# Out:
# 0  Geographic Area Name  \
# 1                 37013
# 2                 37027
# 3                 37067
# 4                 37072
# 5                 37076
#
# 0  Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years  \
# 1                                               9099
# 2                                               4292
# 3                                               2278
# 4                                               2230
# 5                                               3191
#
# 0  Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Less than high school graduate  \
# 1                                               1073
# 2                                                643
# 3                                                227
# 4                                                336
# 5                                                278
#
# ...

# %%
# change column names
edu_df = edu_df.rename(columns={"Geographic Area Name":"zip_code",
                                "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years":"Population 18-24",
                                "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Less than high school graduate":"18-24 not high school graduate",
                                "18-24 highschool" : "18-24 high school graduate",
                                "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Bachelor's degree or higher":"18-24 bachelor's degree or higher",
                                "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 25 to 34 years":"Population 25 to 34 years",
                                "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 35 to 44 years":"Population 35 to 44 years",
                                "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 65 years and over":"Population 65 and up",
                                "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 25 to 34 years!!Bachelor's degree or higher":"25-34 Bachelor's or higher",
                                "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 35 to 44 years!!Bachelor's degree or higher":"35-44 Bachelor's or higher",
                                "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 45 to 64 years!!Bachelor's degree or higher":"45-64 Bachelor's or higher",
                                "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 65 years and over!!Bachelor's degree or higher":"65 and up Bachelor's or higher"
})

# %%
# select desired columns
edu_df = edu_df[["zip_code","Population 18-24","18-24 not high school graduate","18-24 high school graduate","18-24 bachelor's degree or higher","Population 25 to 34 years","25-34 not high school graduate","25-34 high school graduate","25-34 Bachelor's or higher","Population 35 to 44 years","35-44 not high school graduate","35-44 high school graduate","35-44 Bachelor's or higher","Population 65 and up","65 and up not high school graduate","65 and up high school graduate","65 and up Bachelor's or higher"]]
edu_df.head()
# Out:
# 0  zip_code  Population 18-24  18-24 not high school graduate  \
# 1     37013              9099                            1073
# 2     37027              4292                             643
# 3     37067              2278                             227
# 4     37072              2230                             336
# 5     37076              3191                             278
#
# 0  18-24 high school graduate  18-24 bachelor's degree or higher  \
# 1                        6670                               1356
# 2                        2420                               1229
# 3                        1259                                792
# 4                        1583                                311
# 5                        2317                                596
#
# 0  Population 25 to 34 years  25-34 not high school graduate  \
# 1                      19538                            1439
# 2                       4309                              14
# ...

# %%
# set dtype back to object
# change datatype to numeric
edu_df = edu_df.astype(object)

# %%
# inspect headers income_df
income_df.head()
# Out:
#            GEO_ID                  NAME  \
# 0              id  Geographic Area Name
# 1  8600000US37013           ZCTA5 37013
# 2  8600000US37027           ZCTA5 37027
# 3  8600000US37067           ZCTA5 37067
# 4  8600000US37072           ZCTA5 37072
#
#                                       S1902_C01_001E  \
# 0  Estimate!!Number!!HOUSEHOLD INCOME!!All househ...
# 1                                              35597
# 2                                              19950
# 3                                              11643
# 4                                              12533
#
#                                       S1902_C01_001M  \
# 0  Margin of Error!!Number!!HOUSEHOLD INCOME!!All...
# 1                                                617
# 2                                                382
# 3                                                361
# 4                                                464
#
#                                       S1902_C01_002E  \
# ...

# %%
# change header to 1st row edu_df
new_header = income_df.iloc[0]
income_df = income_df[1:]  #drops orriginal headers
income_df.columns = new_header
income_df.head()
# Out:
# 0              id Geographic Area Name  \
# 1  8600000US37013          ZCTA5 37013
# 2  8600000US37027          ZCTA5 37027
# 3  8600000US37067          ZCTA5 37067
# 4  8600000US37072          ZCTA5 37072
# 5  8600000US37076          ZCTA5 37076
#
# 0 Estimate!!Number!!HOUSEHOLD INCOME!!All households  \
# 1                                              35597
# 2                                              19950
# 3                                              11643
# 4                                              12533
# 5                                              17389
#
# 0 Margin of Error!!Number!!HOUSEHOLD INCOME!!All households  \
# 1                                                617
# 2                                                382
# 3                                                361
# 4                                                464
# 5                                                393
#
# ...

# %%
# view all headers
list(income_df.columns.values)
# Out:
# ['id',
#  'Geographic Area Name',
#  'Estimate!!Number!!HOUSEHOLD INCOME!!All households',
#  'Margin of Error!!Number!!HOUSEHOLD INCOME!!All households',
#  'Estimate!!Number!!HOUSEHOLD INCOME!!All households!!With earnings',
#  'Margin of Error!!Number!!HOUSEHOLD INCOME!!All households!!With earnings',
#  'Estimate!!Number!!HOUSEHOLD INCOME!!All households!!With earnings!!With wages or salary income',
#  'Margin of Error!!Number!!HOUSEHOLD INCOME!!All households!!With earnings!!With wages or salary income',
#  'Estimate!!Number!!HOUSEHOLD INCOME!!All households!!With earnings!!With self-employment income',
#  'Margin of Error!!Number!!HOUSEHOLD INCOME!!All households!!With earnings!!With self-employment income',
#  'Estimate!!Number!!HOUSEHOLD INCOME!!All households!!With interest, dividends, or net rental income',
#  'Margin of Error!!Number!!HOUSEHOLD INCOME!!All households!!With interest, dividends, or net rental income',
# ...

# %%
# select columns to keep
income_df = income_df[["Geographic Area Name","Estimate!!Number!!HOUSEHOLD INCOME!!All households"]]
income_df.head()
# Out:
# 0 Geographic Area Name Estimate!!Number!!HOUSEHOLD INCOME!!All households
# 1          ZCTA5 37013                                              35597
# 2          ZCTA5 37027                                              19950
# 3          ZCTA5 37067                                              11643
# 4          ZCTA5 37072                                              12533
# 5          ZCTA5 37076                                              17389

# %%
# change name of Geographic Area Name column to zip_code
income_df = income_df.rename(columns={"Geographic Area Name":"zip_code",
                                "Estimate!!Number!!HOUSEHOLD INCOME!!All households":"average household income"})

# %%
# split zip_code to remove ZCTA5
text_2 = income_df['zip_code'].str.split(' ', n=1, expand=True)
income_df['text']=text_1[0]
income_df['zip_code']=text_2[1]
income_df=income_df.drop(columns='text')
income_df.head()
# Out:
# 0 zip_code average household income
# 1    37013                    35597
# 2    37027                    19950
# 3    37067                    11643
# 4    37072                    12533
# 5    37076                    17389

# %%
len(demo_df)
# Out:
# 32

# %%
len(income_df)
# Out:
# 32

# %%
len(edu_df)
# Out:
# 32

# %%
demo_df.dtypes
# Out:
# 0
# zip_code                   object
# total_population           object
# total_male_population      object
# total_female_popularion    object
# 18+                        object
# 18+Male                    object
# 18+Female                  object
# dtype: object

# %%
edu_df.dtypes
# Out:
# 0
# zip_code                              object
# Population 18-24                      object
# 18-24 not high school graduate        object
# 18-24 high school graduate            object
# 18-24 bachelor's degree or higher     object
# Population 25 to 34 years             object
# 25-34 not high school graduate        object
# 25-34 high school graduate            object
# 25-34 Bachelor's or higher            object
# Population 35 to 44 years             object
# 35-44 not high school graduate        object
# 35-44 high school graduate            object
# 35-44 Bachelor's or higher            object
# Population 65 and up                  object
# 65 and up not high school graduate    object
# 65 and up high school graduate        object
# 65 and up Bachelor's or higher        object
# dtype: object

# %%
income_df.dtypes
# Out:
# 0
# zip_code                    object
# average household income    object
# dtype: object

# %%
demo_df['zip_code']=pd.to_numeric(demo_df['zip_code'])
edu_df['zip_code']=pd.to_numeric(edu_df['zip_code'])
income_df['zip_code']=pd.to_numeric(income_df['zip_code'])

# %%
# join demo adn edu dataframes on zip code
merged_df = demo_df.merge(edu_df, on='zip_code')
#merged_df['zip_code']=pd.to_numeric(merged_df['zip_code'])
merged_df.sort_values(by='zip_code')
#.merge(income_df, on="zip_code")
merged_df
# Out:
# 0   zip_code total_population total_male_population total_female_popularion  \
# 0      37013            97939                 47658                   50281
# 1      37027            56117                 27888                   28229
# 2      37067            29543                 14462                   15081
# 3      37072            31492                 15327                   16165
# 4      37076            40161                 19600                   20561
# 5      37078              380                   194                     186
# 6      37080             7394                  3703                    3691
# 7      37115            40343                 19376                   20967
# 8      37135            14256                  6919                    7337
# 9      37138            23784                 11320                   12464
# 10     37189             4016                  1642                    2374
# ...

# %%
# join merged and income df on zip codes
merged_df = merged_df.merge(income_df, on='zip_code')
merged_df.sort_values(by='zip_code')
merged_df
# Out:
# 0   zip_code total_population total_male_population total_female_popularion  \
# 0      37013            97939                 47658                   50281
# 1      37027            56117                 27888                   28229
# 2      37067            29543                 14462                   15081
# 3      37072            31492                 15327                   16165
# 4      37076            40161                 19600                   20561
# 5      37078              380                   194                     186
# 6      37080             7394                  3703                    3691
# 7      37115            40343                 19376                   20967
# 8      37135            14256                  6919                    7337
# 9      37138            23784                 11320                   12464
# 10     37189             4016                  1642                    2374
# ...

# %%
# export csv files
income_df.to_csv("Resources/income_data_clean.csv")
edu_df.to_csv("Resources/education_data_clean.csv")
demo_df.to_csv("Resources/demographic_data_clean.csv")

# %%
# export merged dataframe
merged_df.to_csv("Resources/all_demographic_data_merged.csv")

# %%
list(merged_df.columns.values)
# Out:
# ['zip_code',
#  'total_population',
#  'total_male_population',
#  'total_female_popularion',
#  '18+',
#  '18+Male',
#  '18+Female',
#  'Population 18-24',
#  '18-24 not high school graduate',
#  '18-24 high school graduate',
#  "18-24 bachelor's degree or higher",
#  'Population 25 to 34 years',
#  '25-34 not high school graduate',
#  '25-34 high school graduate',
#  "25-34 Bachelor's or higher",
#  'Population 35 to 44 years',
#  '35-44 not high school graduate',
#  '35-44 high school graduate',
#  "35-44 Bachelor's or higher",
#  'Population 65 and up',
#  '65 and up not high school graduate',
#  '65 and up high school graduate',
#  "65 and up Bachelor's or higher",
#  'average household income']
