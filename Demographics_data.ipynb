# %%
# Dependencies
import pandas as pd

# %%
# csv to dataFrame
demo_df = pd.read_csv("../Beer_Restaurant_Success/Resources/demographics_by_zip.csv")
edu_df = pd.read_csv("../Beer_Restaurant_Success/Resources/education_by_zip.csv")
income_df = pd.read_csv("../Beer_Restaurant_Success/Resources/income_by_zip.csv")

# %%
# inspect demo_df headers
demo_df.head()
# Out:
#            GEO_ID                  NAME  \
# 0              id  Geographic Area Name
# 1  8600000US37013           ZCTA5 37013
# 2  8600000US37027           ZCTA5 37027
# 3  8600000US37067           ZCTA5 37067
# 4  8600000US37072           ZCTA5 37072
#
#                                 DP05_0001E  \
# 0  Estimate!!SEX AND AGE!!Total population
# 1                                    97939
# 2                                    56117
# 3                                    29543
# 4                                    31492
#
#                                        DP05_0001M  \
# 0  Margin of Error!!SEX AND AGE!!Total population
# 1                                            2456
# 2                                             765
# 3                                            1010
# 4                                             763
#
#                               DP05_0001PE  \
# 0  Percent!!SEX AND AGE!!Total population
# 1                                   97939
# ...

# %%
# change header to 1st row demo_df
new_header = demo_df.iloc[0]
demo_df = demo_df[1:]
demo_df.columns = new_header
demo_df.head()
# Out:
# 0              id Geographic Area Name  \
# 1  8600000US37013          ZCTA5 37013
# 2  8600000US37027          ZCTA5 37027
# 3  8600000US37067          ZCTA5 37067
# 4  8600000US37072          ZCTA5 37072
# 5  8600000US37076          ZCTA5 37076
#
# 0 Estimate!!SEX AND AGE!!Total population  \
# 1                                   97939
# 2                                   56117
# 3                                   29543
# 4                                   31492
# 5                                   40161
#
# 0 Margin of Error!!SEX AND AGE!!Total population  \
# 1                                           2456
# 2                                            765
# 3                                           1010
# 4                                            763
# 5                                           1183
#
# 0 Percent!!SEX AND AGE!!Total population  \
# 1                                  97939
# 2                                  56117
# ...

# %%
# view all headers
list(demo_df.columns.values)
# Out:
# ['id',
#  'Geographic Area Name',
#  'Estimate!!SEX AND AGE!!Total population',
#  'Margin of Error!!SEX AND AGE!!Total population',
#  'Percent!!SEX AND AGE!!Total population',
#  'Percent Margin of Error!!SEX AND AGE!!Total population',
#  'Estimate!!SEX AND AGE!!Total population!!Male',
#  'Margin of Error!!SEX AND AGE!!Total population!!Male',
#  'Percent!!SEX AND AGE!!Total population!!Male',
#  'Percent Margin of Error!!SEX AND AGE!!Total population!!Male',
#  'Estimate!!SEX AND AGE!!Total population!!Female',
#  'Margin of Error!!SEX AND AGE!!Total population!!Female',
#  'Percent!!SEX AND AGE!!Total population!!Female',
#  'Percent Margin of Error!!SEX AND AGE!!Total population!!Female',
#  'Estimate!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)',
#  'Margin of Error!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)',
#  'Percent!!SEX AND AGE!!Total population!!Sex ratio (males per 100 females)',
# ...

# %%
# inspect edu_df headers
edu_df.head()
# Out:
#            GEO_ID                  NAME  \
# 0              id  Geographic Area Name
# 1  8600000US37013           ZCTA5 37013
# 2  8600000US37027           ZCTA5 37027
# 3  8600000US37067           ZCTA5 37067
# 4  8600000US37072           ZCTA5 37072
#
#                                       S1501_C01_001E  \
# 0  Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT...
# 1                                               9099
# 2                                               4292
# 3                                               2278
# 4                                               2230
#
#                                       S1501_C01_001M  \
# 0  Margin of Error!!Total!!AGE BY EDUCATIONAL ATT...
# 1                                                858
# 2                                                594
# 3                                                524
# 4                                                344
#
#                                       S1501_C01_002E  \
# ...

# %%
# change header to 1st row edu_df
new_header = edu_df.iloc[0]
edu_df = edu_df[1:]  #drops orriginal headers
edu_df.columns = new_header
edu_df.head()
# Out:
# 0              id Geographic Area Name  \
# 1  8600000US37013          ZCTA5 37013
# 2  8600000US37027          ZCTA5 37027
# 3  8600000US37067          ZCTA5 37067
# 4  8600000US37072          ZCTA5 37072
# 5  8600000US37076          ZCTA5 37076
#
# 0 Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years  \
# 1                                               9099
# 2                                               4292
# 3                                               2278
# 4                                               2230
# 5                                               3191
#
# 0 Margin of Error!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years  \
# 1                                                858
# 2                                                594
# 3                                                524
# 4                                                344
# 5                                                476
#
# ...

# %%
# view all headers
list(edu_df.columns.values)
# Out:
# ['id',
#  'Geographic Area Name',
#  'Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years',
#  'Margin of Error!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years',
#  'Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Less than high school graduate',
#  'Margin of Error!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Less than high school graduate',
#  'Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!High school graduate (includes equivalency)',
#  'Margin of Error!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!High school graduate (includes equivalency)',
#  "Estimate!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Some college or associate's degree",
#  "Margin of Error!!Total!!AGE BY EDUCATIONAL ATTAINMENT!!Population 18 to 24 years!!Some college or associate's degree",
# ...

# %%
# inspect headers income_df
income_df.head()
# Out:
#            GEO_ID                  NAME  \
# 0              id  Geographic Area Name
# 1  8600000US37013           ZCTA5 37013
# 2  8600000US37027           ZCTA5 37027
# 3  8600000US37067           ZCTA5 37067
# 4  8600000US37072           ZCTA5 37072
#
#                                       S1902_C01_001E  \
# 0  Estimate!!Number!!HOUSEHOLD INCOME!!All househ...
# 1                                              35597
# 2                                              19950
# 3                                              11643
# 4                                              12533
#
#                                       S1902_C01_001M  \
# 0  Margin of Error!!Number!!HOUSEHOLD INCOME!!All...
# 1                                                617
# 2                                                382
# 3                                                361
# 4                                                464
#
#                                       S1902_C01_002E  \
# ...

# %%
# change header to 1st row edu_df
new_header = income_df.iloc[0]
income_df = income_df[1:]  #drops orriginal headers
income_df.columns = new_header
income_df.head()
# Out:
# 0              id Geographic Area Name  \
# 1  8600000US37013          ZCTA5 37013
# 2  8600000US37027          ZCTA5 37027
# 3  8600000US37067          ZCTA5 37067
# 4  8600000US37072          ZCTA5 37072
# 5  8600000US37076          ZCTA5 37076
#
# 0 Estimate!!Number!!HOUSEHOLD INCOME!!All households  \
# 1                                              35597
# 2                                              19950
# 3                                              11643
# 4                                              12533
# 5                                              17389
#
# 0 Margin of Error!!Number!!HOUSEHOLD INCOME!!All households  \
# 1                                                617
# 2                                                382
# 3                                                361
# 4                                                464
# 5                                                393
#
# ...

# %%
# view all headers
list(income_df.columns.values)
# Out:
# ['id',
#  'Geographic Area Name',
#  'Estimate!!Number!!HOUSEHOLD INCOME!!All households',
#  'Margin of Error!!Number!!HOUSEHOLD INCOME!!All households',
#  'Estimate!!Number!!HOUSEHOLD INCOME!!All households!!With earnings',
#  'Margin of Error!!Number!!HOUSEHOLD INCOME!!All households!!With earnings',
#  'Estimate!!Number!!HOUSEHOLD INCOME!!All households!!With earnings!!With wages or salary income',
#  'Margin of Error!!Number!!HOUSEHOLD INCOME!!All households!!With earnings!!With wages or salary income',
#  'Estimate!!Number!!HOUSEHOLD INCOME!!All households!!With earnings!!With self-employment income',
#  'Margin of Error!!Number!!HOUSEHOLD INCOME!!All households!!With earnings!!With self-employment income',
#  'Estimate!!Number!!HOUSEHOLD INCOME!!All households!!With interest, dividends, or net rental income',
#  'Margin of Error!!Number!!HOUSEHOLD INCOME!!All households!!With interest, dividends, or net rental income',
# ...
