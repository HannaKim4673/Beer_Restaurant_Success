# %%
# Initial imports.
import pandas as pd
from path import Path
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
# Loading data
file_path = Path("database_join.csv")
df = pd.read_csv(file_path)
df.head()
# Out:
#    index  zip_code  total_population  total_male_population  \
# 0      0     37013             97939                  47658
# 1     18     37209             38664                  18251
# 2     24     37215             22379                   9989
# 3     15     37206             26382                  12473
# 4     18     37209             38664                  18251
#
#    total_female_popularion  eight_teen_plus  eight_teen_plus_male  \
# 0                    50281            59479                 27984
# 1                    20413            29326                 13363
# 2                    12390            17874                  7986
# 3                    13909            20213                  9555
# 4                    20413            29326                 13363
#
#    eight_teen_plus_female  population_eight_teen_to_twenty_four  \
# 0                   31495                                  9099
# 1                   15963                                  5522
# ...

# %%
# Define the features set.
X = df[["average_household_income","permit_number"]]

X.head()
# Out:
#    average_household_income permit_number
# 0                     26832      19-25846
# 1                     32539      16-20340
# 2                     88326      19-25920
# 3                     36851      19-25985
# 4                     32539      17-25076

# %%
# Use get_dummies() to create variables permit_number.
pn = pd.get_dummies(data=X, columns=["permit_number"])
pn.head()
# Out:
#    average_household_income  permit_number_00-00507  permit_number_00-17595  \
# 0                     26832                       0                       0
# 1                     32539                       0                       0
# 2                     88326                       0                       0
# 3                     36851                       0                       0
# 4                     32539                       0                       0
#
#    permit_number_00-17637  permit_number_00-17649  permit_number_00-17677  \
# 0                       0                       0                       0
# 1                       0                       0                       0
# 2                       0                       0                       0
# 3                       0                       0                       0
# 4                       0                       0                       0
#
# ...

# %%
# Standardize the data with StandardScaler().
permit_scaled = StandardScaler().fit_transform(X)
permit_scaled
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-56f8e0594c69> in <module>
#       1 # Standardize the data with StandardScaler().
# ----> 2 permit_scaled = StandardScaler().fit_transform(X)
#       3 permit_scaled
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\preprocessing\_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
# ...

# %%
y = df["zip_code"].ravel()
y[:5]
# Out:
# array([37013, 37209, 37215, 37206, 37209], dtype=int64)

# %%
# split and train
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Creating a StandardScaler instance.
scaler = StandardScaler()
# Fitting the Standard Scaler with the training data.
X_scaler = scaler.fit(X_train)

# Scaling the data.
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
